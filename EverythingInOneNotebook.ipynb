# %% [markdown]
# ##### Load Data

# %%
import pandas as pd
traindf = pd.read_csv('train.csv')
testdf = pd.read_csv('test.csv')

# %% [markdown]
# ##### Know everything about data - shape , stats, head, tail, col data types info,

# %%
print(traindf.shape)

# %%
traindf.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
traindf.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
traindf.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
type(traindf.BldgType[1]) #### everything with object data type is actually string
# Out:
# str

# %%
# %matplotlib inline
# Why matplotlib inline is used
#It provides interactivity with the backend in the frontends like the jupyter notebook. It also provides the feature where, the plotting commands below the output cell of the previous plot, will not affect the previous plot, which means it separates different plots.
import matplotlib.pyplot as plt

# %%
traindf.hist(bins = 50 , figsize=(16,16))    # Make a histogram of the DataFrame’s columns.
# Out:
# array([[<AxesSubplot:title={'center':'Id'}>,
#         <AxesSubplot:title={'center':'MSSubClass'}>,
#         <AxesSubplot:title={'center':'LotFrontage'}>,
#         <AxesSubplot:title={'center':'LotArea'}>,
#         <AxesSubplot:title={'center':'OverallQual'}>,
#         <AxesSubplot:title={'center':'OverallCond'}>],
#        [<AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'YearRemodAdd'}>,
#         <AxesSubplot:title={'center':'MasVnrArea'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF1'}>,
#         <AxesSubplot:title={'center':'BsmtFinSF2'}>,
#         <AxesSubplot:title={'center':'BsmtUnfSF'}>],
#        [<AxesSubplot:title={'center':'TotalBsmtSF'}>,
#         <AxesSubplot:title={'center':'1stFlrSF'}>,
#         <AxesSubplot:title={'center':'2ndFlrSF'}>,
#         <AxesSubplot:title={'center':'LowQualFinSF'}>,
#         <AxesSubplot:title={'center':'GrLivArea'}>,
#         <AxesSubplot:title={'center':'BsmtFullBath'}>],
# ...

# %% [markdown]
# # --> Feature Selection
#     - Remove constant features (features with 0 variance)
#     - Remove features with less variance
# 	(Doubt : What is the range of value fo the feature itself is low.., then in that case do we first check the min and the max of the  feature, and then compare the variance, and decide variance based selection that way ? )
#     - Remove features with high values of max and min, and very low values of variance ?
#     - See features having high correlation with Target variable. (use either Df.Corr , or numpy.corrcoef on tanspose of DF.Values -- it will give same results)
#     - Build correlation matrix of columns only with high correlation with target variable.
#     - Remove features with high correlation to each other. (How ? Write code) # use pairplots
#     - Start plotting relation of each selected feature to the target variable. (scatter plots)
#     - Check for normal distribution ? Convert to normal distribution ? Do p-value test , t test , z test , ANOVA test (Why and How)
#     - Convert categorical features to one hot encoding ? (How ? When ? )

# %%
threshold = 0.2
traindf.std().sort_values()

# %%
traindf.drop(traindf.std()[traindf.std() < threshold].index.values, axis=1)
# Out:
# C:\Users\lavin\AppData\Local\Temp/ipykernel_37616/2645270408.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   traindf.drop(traindf.std()[traindf.std() < threshold].index.values, axis=1)
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# ...

# %%
corrmat = traindf.corr()
f, ax = plt.subplots(figsize=(16, 16))
plt.imshow(corrmat  , extent = (-10 , 100 , -10 , 100) )
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_yticklabels(traindf.columns.tolist())
ax.set_xticklabels(traindf.columns.tolist())
plt.show()
# Out:
# C:\Users\lavin\AppData\Local\Temp/ipykernel_37616/2516237355.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(traindf.columns.tolist())
# C:\Users\lavin\AppData\Local\Temp/ipykernel_37616/2516237355.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(traindf.columns.tolist())

# %%
import seaborn as sns 
f, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(corrmat)
# Out:
# <AxesSubplot:>

# %%
corrmat = traindf.corr()
f, ax = plt.subplots(figsize=(16, 16))
plt.imshow(corrmat.nlargest(10, 'SalePrice')  , extent = (-10 , 100 , -10 , 100) )
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")

plt.show()

# %%
corrmat = traindf.corr()
corrmat.index
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
corrmat.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
corrmat
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
AbsCorrmatDF = corrmat.abs()
AbsCorrmatDF
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156     0.010601  0.033226     0.028365
# MSSubClass     0.011156    1.000000     0.386347  0.139781     0.032628
# LotFrontage    0.010601    0.386347     1.000000  0.426095     0.251646
# LotArea        0.033226    0.139781     0.426095  1.000000     0.105806
# OverallQual    0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609    0.059316     0.059213  0.005636     0.091932
# YearBuilt      0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd   0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea     0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1     0.005024    0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2     0.005968    0.065649     0.049900  0.111170     0.059119
# BsmtUnfSF      0.007940    0.140759     0.132644  0.002618     0.308159
# ...

# %%
# Find out which features have correlation with target variable more than 0.5, and list their names. 
HighCorrWithTargetTrainDFcolumns = AbsCorrmatDF[AbsCorrmatDF['SalePrice'].between(0.5, 1)] .index
HighCorrWithTargetTrainDFcolumns
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice'],
#       dtype='object')

# %%
trainDF_onlyHighCorrelWithTarget = traindf[HighCorrWithTargetTrainDFcolumns].values.T # Taking only the values of DF in an array and transposing
trainDF_onlyHighCorrelWithTarget
# Out:
# array([[     7,      6,      7, ...,      7,      5,      5],
#        [  2003,   1976,   2001, ...,   1941,   1950,   1965],
#        [  2003,   1976,   2002, ...,   2006,   1996,   1965],
#        ...,
#        [     2,      2,      2, ...,      1,      1,      1],
#        [   548,    460,    608, ...,    252,    240,    276],
#        [208500, 181500, 223500, ..., 266500, 142125, 147500]], dtype=int64)

# %%
import numpy as np
correlation_matrix = np.corrcoef(trainDF_onlyHighCorrelWithTarget)
correlation_matrix
# Out:
# array([[1.        , 0.57232277, 0.55068392, 0.5378085 , 0.47622383,
#         0.59300743, 0.55059971, 0.42745234, 0.60067072, 0.56202176,
#         0.7909816 ],
#        [0.57232277, 1.        , 0.59285498, 0.391452  , 0.28198586,
#         0.19900971, 0.46827079, 0.09558913, 0.53785009, 0.47895382,
#         0.52289733],
#        [0.55068392, 0.59285498, 1.        , 0.29106558, 0.24037927,
#         0.28738852, 0.43904648, 0.19173982, 0.42062215, 0.37159981,
#         0.50710097],
#        [0.5378085 , 0.391452  , 0.29106558, 1.        , 0.81952998,
#         0.4548682 , 0.32372241, 0.28557256, 0.43458483, 0.48666546,
#         0.61358055],
#        [0.47622383, 0.28198586, 0.24037927, 0.81952998, 1.        ,
#         0.56602397, 0.38063749, 0.40951598, 0.43931681, 0.48978165,
#         0.60585218],
#        [0.59300743, 0.19900971, 0.28738852, 0.4548682 , 0.56602397,
#         1.        , 0.63001165, 0.82548937, 0.46724742, 0.46899748,
#         0.70862448],
# ...

# %%
plt.figure(figsize=(16,16))
heat_map = sns.heatmap(correlation_matrix,annot=True, yticklabels=HighCorrWithTargetTrainDFcolumns, xticklabels= HighCorrWithTargetTrainDFcolumns)
plt.show()

# %%
# ANother mehtod for getting the list of most important columns on the basis of correlation with target variable
corr_dict=corrmat['SalePrice'].sort_values(ascending=False).to_dict()
important_columns=[]
for key,value in corr_dict.items():
    if ((value>0.1) & (value<0.8)) | (value<=-0.1):
        important_columns.append(key)
important_columns
# Out:
# ['OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd',
#  'GarageYrBlt',
#  'MasVnrArea',
#  'Fireplaces',
#  'BsmtFinSF1',
#  'LotFrontage',
#  'WoodDeckSF',
#  '2ndFlrSF',
#  'OpenPorchSF',
#  'HalfBath',
#  'LotArea',
#  'BsmtFullBath',
#  'BsmtUnfSF',
#  'BedroomAbvGr',
#  'ScreenPorch',
#  'EnclosedPorch',
#  'KitchenAbvGr']

# %% [markdown]
# ###### For the highly correlated features, Plot Scatter plot OR Swarmplot or BoxPlot to check its pattern with the Target variable, and also detect outliers.

# %%
### With the subplot() function you can draw multiple plots in one figure:

### Returns: This method return the following values.
##fig : This method return the figure layout.
##ax : This method return the axes.Axes object or array of Axes objects
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#       'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#       'SalePrice'],
#      dtype='object')

fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["OverallQual"], traindf["SalePrice"])
ax.set_xlabel("OverallQual")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["YearBuilt"], traindf["SalePrice"])
ax.set_xlabel("YearBuilt")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["YearRemodAdd"], traindf["SalePrice"])
ax.set_xlabel("YearRemodAdd")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["TotalBsmtSF"], traindf["SalePrice"])
ax.set_xlabel("TotalBsmtSF")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["1stFlrSF"], traindf["SalePrice"])
ax.set_xlabel("1stFlrSF")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %% [markdown]
# #

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["GrLivArea"], traindf["SalePrice"])
ax.set_xlabel("GrLivArea")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["FullBath"], traindf["SalePrice"])
ax.set_xlabel("FullBath")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["TotRmsAbvGrd"], traindf["SalePrice"])
ax.set_xlabel("TotRmsAbvGrd")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["GarageCars"], traindf["SalePrice"])
ax.set_xlabel("GarageCars")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
fig , ax = plt.subplots(figsize = (10,6))
ax.grid()
ax.scatter(traindf["GarageArea"], traindf["SalePrice"])
ax.set_xlabel("GarageArea")
ax.set_ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %% [markdown]
# #### Remove Outliers from featues after looking at the scatter plots OR BoxPlots or Swarmplots for categorical variables
#     (When ? Should the outliers be removed before calculating correlation)

# %%
plt.figure(figsize=(40,20))
sns.set(font_scale=1.5)
sns.boxplot(x='YearBuilt', y="SalePrice", data=traindf)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
plt.figure(figsize=(30,30))
sns.swarmplot(x='YearBuilt', y="SalePrice", data=traindf, color=".25")
ax.set_xlabel("GarageArea")
ax.set_ylabel("SalePrice")
# Out:
# C:\Users\lavin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lavin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lavin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lavin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
traindf = traindf[traindf.GrLivArea < 4500] # Removing outliers on basis of scatter plot

# %% [markdown]
# ### Missing Value Handling
#
# filling with constant values OR Means OR Interpolate OR apply a function
#
# METHOD 1
#    - a good way is to find out which columns in the test data have missiing values throughout, and then remove the corresponding coluymns fromt raining data before training starts.
#    - then remove the same set of columns from test data set also....
#    - then check which more column in training dataset does have null values, remove that from test data set also
#
#    OR
# METHOD 2
#    We must combine train and test datasets. Because This processes are must be carried out together.
#
#    (How to identify ? When ? Should these be removed or imputed ? When should they be removed or imputed ?  )

# %%
# METHOD 2 :  Combine the train and test dataset to then find NA and fill NA 

train_test=pd.concat([traindf,testdf],axis=0,sort=False)
train_test.head()
pd.set_option('display.max_rows', 5000)
train_test_null_info=pd.DataFrame(train_test.isnull().sum(),columns=['Count of NaN'])
train_test_dtype_info=pd.DataFrame(train_test.dtypes,columns=['DataTypes'])
train_test_info=pd.concat([train_test_null_info,train_test_dtype_info],axis=1)
train_test_info
# filling with constant values OR Means OR Interpolate OR apply a function
train_test.loc[train_test['Fireplaces']==0,'FireplaceQu']='Nothing'
train_test['LotFrontage'] = train_test['LotFrontage'].fillna(train_test.groupby('1stFlrSF')['LotFrontage'].transform('mean'))
train_test['LotFrontage'].interpolate(method='linear',inplace=True)
train_test['LotFrontage']=train_test['LotFrontage'].astype(int)
train_test['MasVnrArea'] = train_test['MasVnrArea'].fillna(train_test.groupby('MasVnrType')['MasVnrArea'].transform('mean'))
train_test['MasVnrArea'].interpolate(method='linear',inplace=True)
train_test['MasVnrArea']=train_test['MasVnrArea'].astype(int)
train_test["Fence"] = train_test["Fence"].fillna("None")
train_test["FireplaceQu"] = train_test["FireplaceQu"].fillna("None")
train_test["Alley"] = train_test["Alley"].fillna("None")
train_test["PoolQC"] = train_test["PoolQC"].fillna("None")
train_test["MiscFeature"] = train_test["MiscFeature"].fillna("None")
train_test.loc[train_test['BsmtFinSF1']==0,'BsmtFinType1']='Unf'
train_test.loc[train_test['BsmtFinSF2']==0,'BsmtQual']='TA'
# Out:
#                Count of NaN DataTypes
# Id                        0     int64
# MSSubClass                0     int64
# MSZoning                  4    object
# LotFrontage             486   float64
# LotArea                   0     int64
# Street                    0    object
# Alley                  2719    object
# LotShape                  0    object
# LandContour               0    object
# Utilities                 2    object
# LotConfig                 0    object
# LandSlope                 0    object
# Neighborhood              0    object
# Condition1                0    object
# Condition2                0    object
# BldgType                  0    object
# HouseStyle                0    object
# OverallQual               0     int64
# OverallCond               0     int64
# YearBuilt                 0     int64
# YearRemodAdd              0     int64
# RoofStyle                 0    object
# RoofMatl                  0    object
# Exterior1st               1    object
# ...

# %% [markdown]
# ##### Feature Engineering - Functions on columns

# %%
train_test['YrBltRmd']=train_test['YearBuilt']+train_test['YearRemodAdd']
train_test['Total_Square_Feet'] = (train_test['BsmtFinSF1'] + train_test['BsmtFinSF2'] + train_test['1stFlrSF'] + train_test['2ndFlrSF'] + train_test['TotalBsmtSF'])
train_test['Total_Bath'] = (train_test['FullBath'] + (0.5 * train_test['HalfBath']) + train_test['BsmtFullBath'] + (0.5 * train_test['BsmtHalfBath']))
train_test['Total_Porch_Area'] = (train_test['OpenPorchSF'] + train_test['3SsnPorch'] + train_test['EnclosedPorch'] + train_test['ScreenPorch'] + train_test['WoodDeckSF'])
train_test['exists_pool'] = train_test['PoolArea'].apply(lambda x: 1 if x > 0 else 0)
train_test['exists_garage'] = train_test['GarageArea'].apply(lambda x: 1 if x > 0 else 0)
train_test['exists_fireplace'] = train_test['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)
train_test['exists_bsmt'] = train_test['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)
train_test['old_house'] = train_test['YearBuilt'].apply(lambda x: 1 if x <1990 else 0)

for i in train_test.columns:
    if 'SalePrice' not in i:
        if 'object' in str(train_test[str(i)].dtype):
            train_test[str(i)]=train_test[str(i)].fillna(method='ffill')

# %% [markdown]
# ##### Feature Engineering - Label Encoding on categorical columns

# %%
columns = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 'YrSold', 'MoSold', 'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope', 'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond')

for col in columns:
    lbl_enc = LabelEncoder() 
    lbl_enc.fit(list(train_test[col].values)) 
    train_test[col] = lbl_enc.transform(list(train_test[col].values))

# %% [markdown]
# ##### Feature Engineering - checking distribution of data

# %%
##### Feature Engineering - checking distribution of data , each column wise, to see if data of each column is skewed or normal distributuion
# (optional) plot train & test
fig, ax=plt.subplots(1,2)
sns.distplot(train_data, ax=ax[0])
sns.distplot(test_data, ax=ax[1])

# %% [markdown]
# ##### Check missing value - Method 1

# %%
# Check how many columns have how many missing values in train dataset: 
totalmissingfromtrain = traindf.isna().sum().sort_values(ascending=False)

type(totalmissingfromtrain) #--- Series
totalmissingfromtrain.head(90)
# Out:
# PoolQC         1452
# MiscFeature    1404
# Alley          1367
# Fence          1177
# FireplaceQu     690
#                ...
# ExterQual         0
# Exterior2nd       0
# Exterior1st       0
# RoofMatl          0
# SalePrice         0
# Length: 81, dtype: int64

# %%
# concatenate this missing value information into a dataframe
missing_data_count = pd.concat([totalmissingfromtrain], axis=1, keys=["Total"])
missing_data_count.head(45)
# Out:
#                Total
# PoolQC          1452
# MiscFeature     1404
# Alley           1367
# Fence           1177
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# Functional         0
# Fireplaces         0
# KitchenQual        0
# KitchenAbvGr       0
# BedroomAbvGr       0
# HalfBath           0
# FullBath           0
# BsmtHalfBath       0
# TotRmsAbvGrd       0
# GarageCars         0
# GrLivArea          0
# GarageArea         0
# PavedDrive         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# ...

# %%
missing_data_count = missing_data_count[missing_data_count > 0 ] # Check only columns with missing values
missing_data_count = missing_data_count.dropna()
missing_data_count
# Out:
#                Total
# PoolQC        1452.0
# MiscFeature   1404.0
# Alley         1367.0
# Fence         1177.0
# FireplaceQu    690.0
# LotFrontage    259.0
# GarageYrBlt     81.0
# GarageCond      81.0
# GarageType      81.0
# GarageFinish    81.0
# GarageQual      81.0
# BsmtFinType2    38.0
# BsmtExposure    38.0
# BsmtQual        37.0
# BsmtCond        37.0
# BsmtFinType1    37.0
# MasVnrArea       8.0
# MasVnrType       8.0
# Electrical       1.0

# %%
# Plot missing values columns count
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid()
ax.bar(missing_data_count.index , missing_data_count.Total.values )
ax.set_ylabel("No. of missing values", labelpad=10)

ax.xaxis.set_tick_params(rotation=90)
plt.show()

# %%
# Check how many columns have how many missing value s in test dataset:

# %%
totalmissingfromtest = testdf.isna().sum().sort_values(ascending=False)

type(testdf) #--- Series
testdf.head(90)
# concatenate this missing value information into a dataframe
missing_data_count = pd.concat([totalmissingfromtest], axis=1, keys=["Total"])
missing_data_count = missing_data_count[missing_data_count > 0 ] # Check only columns with missing values
missing_data_count = missing_data_count.dropna()
missing_data_count

# Plot missing values columns count
fig, ax = plt.subplots(figsize=(10, 6))
ax.grid()
ax.bar(missing_data_count.index , missing_data_count.Total.values )
ax.set_ylabel("No. of missing values", labelpad=10)

ax.xaxis.set_tick_params(rotation=90)
plt.show()

# %%
# a good way is to find out which columns in the test data have missiing values throughout, and then remove the corresponding coluymns fromt raining data before training starts. 
train_dataset = traindf.drop(missing_data_count[missing_data_count.Total > 0 ].index, axis=1)

# %%
# then remove the same set of columns from test data set also.... 
test_dataset = testdf.dropna(axis=1)

# %%
 #then check which more column in training dataset does have null values, remove that from test data set also 
test_dataset = test_dataset.drop(["Electrical"], axis=1)

# %%
full_dataset = pd.concat([train_dataset, test_dataset])

# %% [markdown]
# ###### HANDLING CATEGORICAL VARIABLES
# get_dummies by pandas
# The equivalent of get_dummies is OneHotEncoder by sklearn
# Another way of Converting the Categorical variables to numbers
# df['colname'] =df['colname'].astype('category').cat.codes

# %%
full_dataset = pd.get_dummies(full_dataset)

# %% [markdown]
# ###### Feature Transformation : Scaling the feature / independent variable's data points.
# StandardScaler follows Standard Normal Distribution (SND). Therefore, it makes mean = 0 and scales the data to unit variance.
# MinMaxScaler scales all the data features in the range [0, 1] or else in the range [-1, 1] if there are negative values in the dataset. This scaling compresses all the inliers in the narrow range [0, 0.005].
# In the presence of outliers, StandardScaler does not guarantee balanced feature scales, due to the influence of the outliers while computing the empirical mean and standard deviation. This leads to the shrinkage in the range of the feature values.
# By using RobustScaler(), we can remove the outliers and then use either StandardScaler or MinMaxScaler for preprocessing the dataset.
# It scales features using statistics that are robust to outliers. This method removes the median and scales the data in the range between 1st quartile and 3rd quartile. i.e., in between 25th quantile and 75th quantile range. This range is also called an Interquartile range.
# The median and the interquartile range are then stored so that it could be used upon future data using the transform method. If outliers are present in the dataset, then the median and the interquartile range provide better results and outperform the sample mean and variance.
# RobustScaler uses the interquartile range so that it is robust to outliers.
# https://www.geeksforgeeks.org/standardscaler-minmaxscaler-and-robustscaler-techniques-ml/

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler, RobustScaler

# %% [markdown]
# ##### Feature engineering -- checking skew of data
# check probability distributions, skewness , kurtosis etc

# %% [markdown]
# ### Checking skew in data
# skewness() function in pandas:
# The DataFrame class of pandas has a method skew() that computes the skewness of the data present in a given axis of the DataFrame object. Skewness is computed for each row or each column of the data present in the DataFrame object
# ######## skewness along the index axis
# df.skew(axis = 0, skipna = True)
# ######## skewness along the columns axis
# df.skew(axis = 1, skipna = True)
#
# If skewness is positive, the data are positively skewed or skewed right, meaning that the right tail of the distribution is longer than the left. If skewness is negative, the data are negatively skewed or skewed left, meaning that the left tail is longer. If skewness = 0, the data are perfectly symmetrical.

# %%
numeric_features = train_test.dtypes[train_test.dtypes != "object"].index
skewed_features = train_test[numeric_features].apply(lambda x: skew(x)).sort_values(ascending=False)
print(skewed_features)

# %%
high_skewness = skewed_features[abs(skewed_features) > 0.9]
skewed_features = high_skewness.index

# %% [markdown]
# ##### Feature transformation for skewed data (NORMALIZATION and STANDARDIZATION)
# Some models may not work properly if the features are not symmetric. For example, models based on distances like KNN or K-means or Linear Regression may fail if the distributions are skewed. In order to make these models work, power transformations will symmetrize the features without affecting their predictive power too much.
# What is Box-Cox function in Python?
# SciPy's stats package provides a function called boxcox for performing box-cox power transformation that takes in original non-normal data as input and returns fitted data along with the lambda value that was used to fit the non-normal distribution to normal distribution.
# https://www.geeksforgeeks.org/box-cox-transformation-using-python/
# Box Cox Transformation & Yeo Johnson transformation from sklearn.preprocessing import Powertransformer
# https://www.youtube.com/watch?v=lV_Z4HbNAx0
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PowerTransformer.html

# %%
# Method 1 - pandas boxcox1p function
for feature in skewed_features:
    train_test[feature] = boxcox1p(train_test[feature], boxcox_normmax(train_test[feature] + 1))

# %%
#### Method 2 : SK LEarn Power Transformation -- Yeo Johnson

from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
data =  train_test[feature]
pt.fit(data)
pt.lambdas_
pt.transform(data)

# %%
#### Method 2 : SK LEarn Power Transformation -- BoxCox

from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='boxcox'')
data =  train_test[feature]
pt.fit(data)
pt.lambdas_
pt.transform(data)

# %% [markdown]
# #### Skew ness and Kurtosis distribution
# Skewness essentially measures the relative size of the two tails. Kurtosis is a measure of the combined sizes of the two tails. It measures the amount of probability in the tails. The value is often compared to the kurtosis of the normal distribution, which is equal to 3.
# https://www.spcforexcel.com/knowledge/basic-statistics/are-skewness-and-kurtosis-useful-statistics#:~:text=Skewness%20essentially%20measures%20the%20relative,which%20is%20equal%20to%203.

# %% [markdown]
# # Splitting Train, Test And Validation

# %%
X_train = full_dataset.iloc[train_dataset.index]
X_test = full_dataset.iloc[test_dataset.index]

# %%
X_train = X_train.drop(["SalePrice"], axis=1)

# %%
X_train.shape
# Out:
# (1458, 154)

# %%
X_test.shape
X_test
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
# 0     1461          20    11622            5            6       1961
#
#       YearRemodAdd  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  Electrical_SBrkr  \
# ...

# %%
y_train = train_dataset.SalePrice
y_train.shape
# Out:
# (1458,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.8, random_state=42)

# %%
X_train.isna().sum().sort_values(ascending=False)
# Out:
# Id                       0
# RoofMatl_CompShg         0
# HouseStyle_SLvl          0
# RoofStyle_Flat           0
# RoofStyle_Gable          0
#                         ..
# Neighborhood_Gilbert     0
# Neighborhood_IDOTRR      0
# Neighborhood_MeadowV     0
# Neighborhood_Mitchel     0
# SaleCondition_Partial    0
# Length: 154, dtype: int64

# %%
##### Feature Selection -  Dimensionality Reduction
https://www.youtube.com/watch?v=OFyyWcw2cyM&t=16s

# %% [markdown]
# ##  Regression
# https://www.analyticsvidhya.com/blog/2015/08/comprehensive-guide-regression/

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy.stats import zscore
regressor = LinearRegression()
regressor.fit(X_train, y_train)
regressor.score(X_val, y_val)
# Out:
# 0.014656716430552885

# %%
regressor.coef_
# Out:
# array([-5.03607684e+00, -2.28314379e+01,  5.21606828e-01,  3.75831642e+03,
#        -5.82602296e+02,  9.45612624e+01,  1.84920892e+01,  1.64891256e+01,
#         4.10491402e+01, -4.96665540e+01,  7.87171299e+00, -7.73069057e+03,
#        -6.96161205e+03, -1.48700432e+03, -6.91221809e+03, -2.91293769e+03,
#         4.18120691e+03, -2.27586835e+01, -4.35136098e+01, -3.28296369e+01,
#         2.54380151e+01, -2.93856907e+01,  1.66217941e+02,  5.93920011e-01,
#         3.31530997e+02, -2.58928685e+03,  1.95847892e+04, -1.95847892e+04,
#        -7.11985873e+03,  3.66943345e+03,  8.88502356e+03, -5.43459828e+03,
#         2.62867822e+02, -4.65706367e+01, -1.33727940e+04,  1.31564968e+04,
#         5.66571249e+03, -3.06681934e+03,  1.16164496e+04, -2.30628363e+04,
#         8.84749353e+03, -1.73866709e+04,  3.01466632e+04, -1.27599923e+04,
#        -2.47763926e+04, -1.88300024e+04,  2.71491814e+03,  1.43513266e+04,
# ...

# %%
regressor.intercept_
# Out:
# 5008293.964206105

# %%
y_test = X_test["SalePrice"]
X_test_onlyfeatures = X_test.drop(["SalePrice"] , axis = 1)

# %% [markdown]
# ##### Predictions using Linear Regressor Model

# %%
y_preds = regressor.predict(X_test_onlyfeatures)

# %%
y_test.shape
# Out:
# (1459,)

# %%
y_test.isna().sum()
# Out:
# 1

# %%
y_test.dropna()
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1458, dtype: float64

# %%
y_preds.size
# Out:
# 1459

# %%
y_test = y_test.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
y_test = y_test.values.astype(np.float)
# Out:
# C:\Users\lavin\AppData\Local\Temp/ipykernel_37616/2937634304.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_test = y_test.values.astype(np.float)

# %%
y_preds = y_preds.astype(np.float)
# Out:
# C:\Users\lavin\AppData\Local\Temp/ipykernel_37616/4001501630.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y_preds = y_preds.astype(np.float)

# %% [markdown]
# ###### Scoring : Linear Regression Model --- Mean Squared Error (MSE) / SSres and R2

# %%
mean_squared_error(y_test, y_preds)
# Out:
# 3476952553.3073783

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_preds)
# Out:
# 0.4509979692453012

# %% [markdown]
# ###### Classification : XG Boost Regressor

# %%
import xgboost
xgb_reg = xgboost.XGBRegressor()
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_preds = xgb_reg.predict(X_test_onlyfeatures)

# %% [markdown]
# ###### Classification : XG Boost Regressor --- MSE and R2

# %%
mean_squared_error(y_test, y_preds)
# Out:
# 7430356350.055938

# %%
r2_score(y_test, y_preds)
# Out:
# -0.17323451006872403

# %%
######### CROSS VALIDATIONS 
from sklearn.model_selection import GridSearchCV , RandomizedSearchCV

# %%
####### More Scoring methods : ROC AUC Score, Balanced Accuracy Score
from sklearn.metrics import roc_auc_score,balanced_accuracy_score
